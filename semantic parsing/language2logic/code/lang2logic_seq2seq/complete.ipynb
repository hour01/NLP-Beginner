# %%
import os
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
! /opt/bin/nvidia-smi
os.chdir("/content/drive/MyDrive/lang2logic/")
# !ls
# Out:
# Wed Mar  1 11:11:22 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.85.12    Driver Version: 525.85.12    CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   50C    P0    27W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
! python main.py --dropout 0
# Out:
# starting load...
# ./processed_data/train.pkl_size:4434
# ./processed_data/dev.pkl_size:939
# ./processed_data/test.pkl_size:448
# loading time: 1.6129882335662842
# Epoch: 01 | Epoch Time: 0m 28s
# TrainLoss:  20.8680 | Acc:  11.0756
# Epoch: 02 | Epoch Time: 0m 30s
# TrainLoss:   9.0039 | Acc:   5.9638
# Epoch: 03 | Epoch Time: 0m 29s
# TrainLoss:   7.4738 | Acc:  15.8679
# Epoch: 04 | Epoch Time: 0m 28s
# TrainLoss:   6.4614 | Acc:  21.7252
# Epoch: 05 | Epoch Time: 0m 29s
# TrainLoss:   5.7732 | Acc:  25.6656
# Epoch: 06 | Epoch Time: 0m 29s
# TrainLoss:   5.1691 | Acc:  26.3046
# Epoch: 07 | Epoch Time: 0m 29s
# TrainLoss:   4.7346 | Acc:  26.3046
# Epoch: 08 | Epoch Time: 0m 29s
# TrainLoss:   4.4866 | Acc:  33.1203
# Epoch: 09 | Epoch Time: 0m 29s
# TrainLoss:   4.1765 | Acc:  34.0788
# Epoch: 10 | Epoch Time: 0m 29s
# TrainLoss:   3.9720 | Acc:  30.3514
# Epoch: 11 | Epoch Time: 0m 31s
# TrainLoss:   3.7344 | Acc:  33.4398
# Epoch: 12 | Epoch Time: 0m 29s
# ...

# %%
! python main.py --mode test --

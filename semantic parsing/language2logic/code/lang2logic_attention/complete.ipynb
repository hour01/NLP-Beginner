# %%
import os
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
! /opt/bin/nvidia-smi
os.chdir("/content/drive/MyDrive/lang2logic_attention/")
# !ls
# Out:
# Wed Mar  1 09:44:37 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.85.12    Driver Version: 525.85.12    CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   45C    P0    25W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
! python main.py
# Out:
# starting load...
# ./processed_data/train.pkl_size:4434
# ./processed_data/dev.pkl_size:939
# ./processed_data/test.pkl_size:448
# loading time: 7.005609512329102
# Epoch: 01 | Epoch Time: 0m 56s
# TrainLoss:  58.8818 | Acc:  16.1874
# Epoch: 02 | Epoch Time: 0m 55s
# TrainLoss:  11.1192 | Acc:  35.8892
# Epoch: 03 | Epoch Time: 0m 58s
# TrainLoss:   7.0363 | Acc:  47.7103
# Epoch: 04 | Epoch Time: 0m 55s
# TrainLoss:   5.7240 | Acc:  58.8924
# Epoch: 05 | Epoch Time: 0m 54s
# TrainLoss:   5.0320 | Acc:  63.7913
# Epoch: 06 | Epoch Time: 0m 55s
# TrainLoss:   4.6215 | Acc:  66.6667
# Epoch: 07 | Epoch Time: 0m 55s
# TrainLoss:   4.3986 | Acc:  70.2875
# Epoch: 08 | Epoch Time: 0m 55s
# TrainLoss:   4.0604 | Acc:  67.5186
# Epoch: 09 | Epoch Time: 0m 55s
# TrainLoss:   3.8959 | Acc:  72.0980
# Epoch: 10 | Epoch Time: 0m 55s
# TrainLoss:   3.7179 | Acc:  73.8019
# Epoch: 11 | Epoch Time: 0m 55s
# TrainLoss:   3.5961 | Acc:  72.9499
# Epoch: 12 | Epoch Time: 0m 54s
# ...

# %%
! python main.py --mode test --restore ./CKPT/ckpt_best_acc.pt
# Out:
# starting load...
# ./processed_data/train.pkl_size:4434
# ./processed_data/dev.pkl_size:939
# ./processed_data/test.pkl_size:448
# loading time: 1.6471431255340576
# Test Acc:18.75
